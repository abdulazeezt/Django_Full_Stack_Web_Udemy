# %% [markdown]
# # Videos And Materials At Site  As on:   2025-May-22

# %% [markdown]
# ## <span style='color:DarkBlue'> Section 1: Course Introduction.
# </span>

# %% [markdown]
# ![image.png](attachment:aa76c015-6880-49d5-8b0b-895ce71bd148.png)

# %% [markdown]
# ## <span style='color:DarkBlue'> Section 2 Front0-End Introduction
# </span>

# %% [markdown]
# Play
# 6. What is the Web?
# 7min

# %% [markdown]
# # Play
# 6. What is the Web?
# 7min

# %% [markdown]
# ## <span style='color:DarkBlue'>  Section 3 HTML Level One - Basics
# </span>

# %% [markdown]
# Play
# 7. HTML Level One Introduction
# 1min
# Play
# 8. HTML Part One Basics
# 6min
# Play
# 9. HTML Level One - Part Two -Basic Tagging
# 13min
# Play
# 10. HTML Level One -Part Three - Lists
# 5min
# Play
# 11. HTML Level One -Part Four - Divs and Spans
# 5min
# Play
# 12. HTML Level One - Part Five - Attributes
# 10min
# Play
# 13. HTML Level One Assessment - Overview
# 3min
# Play
# 14. HTML Level One Assessment Solutions
# 7min

# %%
Play
7. HTML Level One Introduction
1min
Play
8. HTML Part One Basics
6min
Play
9. HTML Level One - Part Two -Basic Tagging
13min
Play
10. HTML Level One -Part Three - Lists
5min
Play
11. HTML Level One -Part Four - Divs and Spans
5min
Play
12. HTML Level One - Part Five - Attributes
10min
Play
13. HTML Level One Assessment - Overview
3min
Play
14. HTML Level One Assessment Solutions
7min
# Out:
#   Cell In[5], line 2
#     7. HTML Level One Introduction
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## <span style='color:DarkBlue'>  Section 4 HTML Level Two - Advanced
# </span>

# %% [markdown]
# Play
# 15. HTML Level Two Introduction
# 1min
# Play
# 16. HTML Level Two - Part One - Tables
# 7min
# Play
# 17. HTML Level Two - Part Two Tables Quiz
# 2min
# Play
# 18. HTML Level Two - Part Three Table Quiz Solutions
# 6min
# Play
# 19. HTML Level Two Part Four - Forms Basics
# 12min
# Play
# 20. HTML Level Two - Part Five Forms and Labels
# 14min
# Play
# 21. HTML Level Two - Part Six Forms and Selections
# 12min
# Play
# 22. HTML Level Two - Assessment
# 2min
# Play
# 23. HTML Level Two - Assessment Solutions
# 12min

# %% [markdown]
# ## <span style='color:DarkBlue'> Section 5: CSS Level On - Basics
# </span>

# %% [markdown]
# Play
# 24. CSS Level One Intro
# 4min
# Play
# 25. CSS Level One Part One
# 15min
# Play
# 26. CSS Level One Part Two
# 11min
# Start
# 27. Quick Note about next lecture
# 1min
# Play
# 28. CSS Level One Part Three
# 13min
# Play
# 29. CSS Level One Part Four
# 4min
# Play
# 30. CSS Level One Part Five
# 5min
# Play
# 31. CSS Level One Assessment
# 4min
# Play
# 32. CSS Level One Assessment Solutions
# 7min

# %% [markdown]
# ## <span style='color:DarkBlue'> Section 6: CSS Level Two - Advanced
# </span>

# %% [markdown]
#     Play
#     33. CSS Level Two Introduction
#     1min
#     Play
#     34. CSS Level Two - Part One Fonts
#     12min
#     Play
#     35. CSS Level Two - Part One (Fonts) Continued
#     8min
#     Play
#     36. CSS Level Two - Part Two Box Model
#     9min
#     Play
#     37. CSS Level Two Spectrum Project Overview
#     4min
#     Play
#     38. CSS Level Two Spectrum Project Solutions
#     9min

# %% [markdown]
# ## <span style='color:DarkBlue'> Section 7: Capstone Project One
# </span>

# %% [markdown]
# 39. Capstone Project One Overview
# 3min
# Play
# 40. Capstone Project One Solutions
# 9min
# Play
# 41. Capstone Project One Solutions (Continued)
# 8min

# %% [markdown]
# ## <span style='color:DarkBlue'> Section 8: Bootstrap Overview
# </span>

# %%
42. Bootstrap Introduction
9min
Play
43. Bootstrap Part One - Buttons
12min
Play
44. Bootstrap Part Two Forms
13min
Play
45. Bootstrap Part Three Navbars
18min
Play
46. Bootstrap Part Four - Grids
18min
Play
47. Bootstrap Project
5min
Play
48. Bootstrap Project Solutions
17min

# %% [markdown]
# ## <span style='color:DarkBlue'> Section 9: Javascript Level One - Basics.
# </span>

# %%
    Play
    49. JS Level One Introduction
    1min
    Play
    50. JS Level One - Part One Basics
    18min
    Play
    51. JS Level One - Part Two Connecting Javascript
    4min
    Play
    52. JS Level One - Part Three Exercise
    3min
    Play
    53. JS Level One - Part Three Solutions
    2min
    Play
    54. JS Level One - Part Four - Operators
    12min
    Play
    55. JS Level One - Part Five - Control Flow
    14min
    Play
    56. JS Level One - Part Six While Loops
    9min
    Play
    57. JS Level One - Part Seven For Loops
    8min
    Play
    58. JS Level One Part Eight Loop Exercises
    1min
    Play
    59. JS Level One - Part Eight Solutions
    4min
    Play
    60. JS Level One - Project Overview
    5min
    Play
    61. JS Level One - Part Nine Project Solutions
    9min

# %% [markdown]
# ## <span style='color:DarkBlue'> Section 10: Javascript Level Two.
# </span>

# %%
62. JS Level Two - Introduction
1min
Play
63. JS Level Two - Part One - Functions
20min
Play
64. JS Level Two - Part Two Function Exercises
2min
Play
65. JS Level Two - Part Two Function Solutions
14min
Play
66. JS Level Two - Part Three Arrays
16min
Play
67. JS Level Two - Part Four Array Exercise Overview
5min
Play
68. JS Level Two - Part Four Array Solutions
7min
Play
69. JS Level Two Part Five Objects
11min
Play
70. JS Level Two Part Five Objects Continued
8min
Play
71. JS Level Two Part Six Object Exercises
2min
Play
72. JS Level Two Part Six Object Exercise Solutions
4min
# Out:
#   Cell In[6], line 1
#     62. JS Level Two - Introduction
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## <span style='color:DarkBlue'> Section 11: Document Object Model.
# </span>

# %% [markdown]
# ## <span style='color:DarkBlue'> Section 12: JQuery
# </span>

# %% [markdown]
# ## <span style='color:DarkBlue'> Section 13: Back-End Introduction
# </span>

# %% [markdown]
# ## <span style='color:DarkBlue'> Section 14: Python - Level One.
# </span>

# %% [markdown]
# ## <span style='color:DarkBlue'> Section 14: Python - Level One.
# </span>

# %% [markdown]
# ## <span style='color:DarkBlue'> Section 14: Python - Level One.
# </span>
